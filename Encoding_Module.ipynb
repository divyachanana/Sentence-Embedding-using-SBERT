# %%
#reading preprocessed Data from Excel
import pandas as pd
f = pd.read_excel("df.xlsx")
df=pd.DataFrame(f)

# %%
df.head(10)
# Out:
#          asin                                           question  \
# 0  B00004U9JP  I have a 9 year old Badger 1 that needs replac...
# 1  B00004U9JP                                       model number
# 2  B00004U9JP  can I replace Badger 1 1/3 with a Badger 5 1/2...
# 3  B00004U9JP  Does this come with power cord and dishwasher ...
# 4  B00004U9JP  loud noise inside when turned on. sounds like ...
# 5  B00004U9JP                  where is the reset button located
# 6  B00004U9JO  I have a badger 5 it is leaking water at botto...
# 7  B00004U9JO  If no power cord is included, how do I plug in...
# 8  B00004U9JO  Can someone tell me if this Badger 5 disposer ...
# 9  B00004U9JO  Is this Badger 5 compatible with the Badger 5 ...
#
#                                               answer
# 0   I replaced my old one with this without a hitch.
# 1  This may help InSinkErator Model BADGER-1: Bad...
# 2  Plumbing connections will vary with different ...
# ...

# %%
#encoding questions from data set
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
el = model.encode(df['question'])
el
# Out:
# array([[-0.02221787, -0.01164245,  0.11655894, ..., -0.02111083,
#          0.08600272, -0.0603206 ],
#        [-0.07741269, -0.05752602, -0.00688537, ...,  0.00501785,
#         -0.0377804 , -0.02708601],
#        [-0.05877701, -0.05724511,  0.02477578, ..., -0.04405867,
#          0.07434504, -0.07595611],
#        ...,
#        [-0.07320231, -0.0234781 , -0.01825211, ...,  0.04509936,
#          0.04916541,  0.06534129],
#        [-0.09940945,  0.06263978, -0.09376583, ..., -0.04444065,
#          0.11548276, -0.02664197],
#        [-0.05477903,  0.02534903,  0.01690766, ...,  0.01388146,
#          0.12014599, -0.03142671]], dtype=float32)

# %%
len(el)
# Out:
# 9008

# %%
#converting list of encodings in to dataframe
kd=pd.DataFrame(el)
kd
# Out:
#            0         1         2         3         4         5         6    \
# 0    -0.022218 -0.011642  0.116559 -0.066031  0.013915 -0.033175 -0.071029
# 1    -0.077413 -0.057526 -0.006885 -0.006970  0.002321  0.105237 -0.044073
# 2    -0.058777 -0.057245  0.024776 -0.047540 -0.048675 -0.055482 -0.076670
# 3    -0.051383  0.067538  0.033719  0.027045  0.003451  0.002588 -0.001151
# 4     0.043281 -0.086591  0.003192  0.041338 -0.003385 -0.068019 -0.008901
# ...        ...       ...       ...       ...       ...       ...       ...
# 9003 -0.015998 -0.069186 -0.015558 -0.096347  0.043902 -0.012930  0.025017
# 9004 -0.053369 -0.022163 -0.006467 -0.090900  0.080175  0.038299 -0.037977
# 9005 -0.073202 -0.023478 -0.018252 -0.012150  0.078058 -0.031875  0.024147
# 9006 -0.099409  0.062640 -0.093766 -0.026216 -0.009509  0.002335 -0.019376
# 9007 -0.054779  0.025349  0.016908 -0.018468  0.096308 -0.023004 -0.015794
#
# ...

# %%
#creating a excel file and uploading encoding data frame to it
kd.to_excel('amz_encode.xlsx')

# %%
#reading encodings from excel file
kf = pd.read_excel("amz_encode.xlsx")
kd=pd.DataFrame(kf)
kd
# Out:
#             asin         0         1         2         3         4         5  \
# 0     B00004U9JP -0.022218 -0.011642  0.116559 -0.066031  0.013915 -0.033175
# 1     B00004U9JP -0.077413 -0.057526 -0.006885 -0.006970  0.002321  0.105237
# 2     B00004U9JP -0.058777 -0.057245  0.024776 -0.047540 -0.048675 -0.055482
# 3     B00004U9JP -0.051383  0.067538  0.033719  0.027045  0.003451  0.002588
# 4     B00004U9JP  0.043281 -0.086591  0.003192  0.041338 -0.003385 -0.068019
# ...          ...       ...       ...       ...       ...       ...       ...
# 9003  B00L07RWJE -0.015998 -0.069186 -0.015558 -0.096347  0.043902 -0.012930
# 9004  B00L07RWJE -0.053369 -0.022163 -0.006467 -0.090900  0.080175  0.038299
# 9005  B00L07RWJE -0.073202 -0.023478 -0.018252 -0.012150  0.078058 -0.031875
# 9006  B00L07RWJE -0.099409  0.062640 -0.093766 -0.026216 -0.009509  0.002335
# 9007  B00L07RWJE -0.054779  0.025349  0.016908 -0.018468  0.096308 -0.023004
#
# ...

# %%
sd=kd[kd['asin']=='B00004U9JP']

# %%
sd[list(range(384))]
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.022218 -0.011642  0.116559 -0.066031  0.013915 -0.033175 -0.071029
# 1 -0.077413 -0.057526 -0.006885 -0.006970  0.002321  0.105237 -0.044073
# 2 -0.058777 -0.057245  0.024776 -0.047540 -0.048675 -0.055482 -0.076670
# 3 -0.051383  0.067538  0.033719  0.027045  0.003451  0.002588 -0.001151
# 4  0.043281 -0.086591  0.003192  0.041338 -0.003385 -0.068019 -0.008901
# 5 -0.062231 -0.054148 -0.066411  0.045775  0.001372  0.091942  0.055375
#
#         7         8         9    ...       374       375       376       377  \
# 0  0.022079 -0.081996 -0.021524  ... -0.037192  0.009545  0.011001 -0.036239
# 1  0.066958  0.027799 -0.087622  ... -0.144767  0.000075  0.013206 -0.019880
# 2  0.004429 -0.052545  0.007743  ... -0.060220 -0.019289 -0.033060 -0.057935
# 3 -0.064802  0.047599  0.025940  ... -0.061639  0.051483 -0.037612  0.051642
# 4 -0.067777  0.044770 -0.025798  ...  0.037959  0.064283  0.002173  0.042096
# ...

# %%
arr = sd[list(range(384))].to_numpy()
arr
# Out:
# array([[-0.02221787, -0.01164245,  0.11655894, ..., -0.02111083,
#          0.08600272, -0.0603206 ],
#        [-0.07741269, -0.05752602, -0.00688537, ...,  0.00501785,
#         -0.0377804 , -0.02708601],
#        [-0.05877701, -0.05724511,  0.02477578, ..., -0.04405867,
#          0.07434504, -0.07595611],
#        [-0.05138291,  0.06753778,  0.03371909, ..., -0.02105083,
#          0.03759655, -0.11513392],
#        [ 0.04328077, -0.08659058,  0.0031923 , ..., -0.0224769 ,
#         -0.0169162 ,  0.02396511],
#        [-0.06223109, -0.05414836, -0.0664112 , ...,  0.10730246,
#         -0.06356779, -0.05508814]])
